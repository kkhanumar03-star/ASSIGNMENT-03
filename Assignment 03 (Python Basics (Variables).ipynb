# %% [markdown]
# ## Part -1 Python Basics (Variables)

# %% [markdown]
# 1. Print Your Name with your Father name and Date of birth using suitable escape sequence charactor

# %%
name = "Umar Khan"
father_name = "Shahid Abdullah"
dob = "28-06-2010"

print("Name:", name, "\nFather Name:",Father_name, "\nDate of Birth:", dob)
# Out:
# Name: Umar Khan
# Father Name: Shahid
# Date of Birth: 28-06-2010

# %% [markdown]
# 2. Write your small bio using variables and print it using print function

# %%
name = "Umar Khan"
age = 16
city = "Karachi"
course = "JavaScript and Python"

print("My name is", name)
print("I am", age, "years old")
print("I live in", city)
print("My courses are:", course)
# Out:
# My name is Umar Khan
# I am 16 years old
# I live in Karachi
# My courses are: JavaScript and Python

# %% [markdown]
# 3. Write a program in which use all the operators we can use in Python

# %%
a = 10
b = 3

print("Arithmetic:")
print("a + b =", a + b)  # Addition
print("a - b =", a - b)  # Subtraction
print("a * b =", a * b)  # Multiplication
print("a / b =", a / b)  # Division
print("a // b =", a // b) # Floor Division
print("a % b =", a % b)  # Modulus
print("a ** b =", a ** b) # Exponent

print("\nComparison:")
print("a > b:", a > b)   # Greater than
print("a < b:", a < b)   # Less than
print("a == b:", a == b) # Equal to
print("a != b:", a != b) # Not equal
# Out:
# Arithmetic:
# a + b = 13
# a - b = 7
# a * b = 30
# a / b = 3.3333333333333335
# a // b = 3
# a % b = 1
# a ** b = 1000
#
# Comparison:
# a > b: True
# a < b: False
# a == b: False
# a != b: True

# %% [markdown]
# 4. Completes the following steps of small task:
# Mention Marks of English , Islamiat and Maths out of 100 in 3 different variables
# Mention Variable of Total Marks and assign 300 to it
# Calculate Percentage

# %%
english = 82
islamiat = 84
maths = 88

total_marks = 300 # 100+100+100
obtained = english + islamiat + maths

percentage = (obtained / total_marks) * 100

print("English:", english)
print("Islamiat:", islamiat)
print("Maths:", maths)
print( "Total Marks:", obtained,"out of", total_marks)
print("Percentage:", percentage, "%")
# Out:
# English: 82
# Islamiat: 84
# Maths: 88
# Total Marks: 254 out of 300
# Percentage: 84.66666666666667 %
